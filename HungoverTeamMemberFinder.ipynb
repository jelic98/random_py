# %%
import time
import requests
from datetime import date

# %%
email = 'ljelic.mam2022@london.edu'
headers = {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6ImpTMVhvMU9XRGpfNTJ2YndHTmd2UU8yVnpNYyJ9.....JiNdSOFy1xdclyUl1mLNCkfD8Ohwvnu2iLT2MUBxRT5h3SVytLxecRcCx7WE_G-c8p04XuK7LqbV74_cwX-rVBwGoQ7J6oDwh_1coyzOxAV-PMvQ8MMxCxgRh1yJ8wWkkh_LELPlFBwbYlfjB3GbXFRhX61CIOYyIe6AxZ1WO3zk55AMaqw-_ykODzxiH1nVtBtrNRg_03hlViXPFRLMWpdKey06HzSAsONtoVJ2S0EafvysYIMTioBSERhTGqueXag3KLA8ECGIgYATAoqHhtaOPlW3VnMrjr4ezvh1lMocR3ckvQ51AMPatUolEhqKsufd07PBTdRsI1JSLU41_w'}

# %%
rooms, buildings = [], ['Susx Plc', 'SOC', 'NB']

for b in buildings:
    url = f'https://lbsmobile-webapi.london.edu/api/site/{b}/rooms'
    data = requests.get(url, headers=headers).json()
    rooms.extend([r['RoomId'] for r in data['Rooms']])

# %%
bookings, today = [], date.today().strftime("%Y-%m-%d")

for r in rooms:
    url = f'https://lbsmobile-webapi.london.edu/api/room/{r}/bookings/{today}'
    data = requests.get(url, headers=headers).json()
    bookings.extend([(b['RoomId'], b['BookedBy'], b['StartTime'], b['FinishTime']) for b in data['Bookings']])
    time.sleep(5)

print(bookings)

# %%
for b in bookings:
    if b[1] == email:
        print('Room {} is booked by {} from {} to {}' % b)
